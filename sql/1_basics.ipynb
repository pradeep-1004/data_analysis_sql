# %%
# %sql
select * from learning_pradeep.new_data.customers_delta

# %%
# %sql
select state , country , customer_name from learning_pradeep.new_data.customers_delta

# %%
# %sql
select * from learning_pradeep.new_data.customers_delta where country = 'India'

# %%
# %sql
select * from learning_pradeep.new_data.customers_delta WHERE country <> 'India'

# %%
# %sql
select distinct country from learning_pradeep.new_data.customers_delta

# %%
# %sql
SELECT customer_name , created_date FROM learning_pradeep.new_data.customers_delta
ORDER BY created_date DESC;

# %%
# %sql
--between 

select * from learning_pradeep.new_data.customers_delta where created_date between '2023-02-15' and '2023-05-20'

# %%
# %sql
select * from learning_pradeep.new_data.customers_delta where country in ('USA')

# %%
# %sql
select customer_name from learning_pradeep.new_data.customers_delta where customer_name like '%a%'

# %%
# %sql
select * from learning_pradeep.new_data.orders_delta

# %%
# %sql
select * from learning_pradeep.new_data.orders_delta where customer_id is null

# %%
# %sql
select * from learning_pradeep.new_data.orders_delta where customer_id is not null

# %%
# %sql
--case when 
select amount ,
case 
  when amount < 500 then 'cheap'
  when amount between 500 and 1000 then 'medium'
  else 'expensive'
  
end as price_cata
from learning_pradeep.new_data.orders_delta
