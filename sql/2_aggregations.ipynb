-- %%
select * from learning_pradeep.new_data.orders_delta

-- %%
select count(customer_id) from learning_pradeep.new_data.orders_delta

-- %%
select sum(amount) as total_revenue from learning_pradeep.new_data.orders_delta

-- %%
SELECT AVG(amount) AS avg_amount FROM learning_pradeep.new_data.orders_delta;

-- %%
SELECT 
  FORMAT_NUMBER(AVG(amount), 2) AS avg_amount 
FROM learning_pradeep.new_data.orders_delta

-- %%
select sum(amount) as total_revenue from learning_pradeep.new_data.orders_delta group by customer_id

-- %%
SELECT customer_id,
       amount,
       COUNT(*) AS order_count
FROM learning_pradeep.new_data.orders_delta
GROUP BY customer_id, amount;

-- %%
select customer_id,product_id,sum(amount) as total_spent from learning_pradeep.new_data.orders_delta group by product_id , customer_id having total_spent > 1000;
