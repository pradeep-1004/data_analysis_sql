-- %%
show tables in learning_pradeep.sql_exe

-- %%
select c.customer_id,c.customer_name,o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
inner join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id

-- %%
select c.customer_id,c.customer_name,o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
left join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id

-- %%
select c.customer_id,c.customer_name,o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
right join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id

-- %%
select c.customer_id,c.customer_name,o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
full outer join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id

-- %%
select c.customer_id,c.customer_name,o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
cross join learning_pradeep.sql_exe.dim_customer c

-- %%
select o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
semi join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id

-- %%
select o.order_id,o.amount

from learning_pradeep.sql_exe.fact_orders o 
anti join learning_pradeep.sql_exe.dim_customer c 
on o.customer_id = c.customer_id
