-- %%
select * from learning_pradeep.sql_exe.dim_customer

-- %%
select customer_name , customer_id from learning_pradeep.sql_exe.dim_customer where country = 'USA'

-- %%
select * from learning_pradeep.sql_exe.dim_customer where signup_date between '2022-01-10' and '2025-01-20'

-- %%
select * from learning_pradeep.sql_exe.dim_customer where country in ('USA','UK')

-- %%
--like 

select * from learning_pradeep.sql_exe.dim_customer where signup_date like '2022%'

-- %%
select distinct country from learning_pradeep.sql_exe.dim_customer

-- %%
select * from learning_pradeep.sql_exe.dim_customer 
order by signup_date desc

-- %%
--case when 

select * ,
  case
    when signup_date > '2023-01-01' then 'new'
    when signup_date between '2022-01-01' and '2023-01-01' then 'old'
    else 'very old'
  end as customer_status

from learning_pradeep.sql_exe.dim_customer

-- %%
SELECT COALESCE(country, 'Unknown') AS country
FROM learning_pradeep.sql_exe.dim_customer

-- %%
select upper(customer_name ),
lower(country)

from learning_pradeep.sql_exe.dim_customer

-- %%
select year(signup_date) as year,
day(signup_date) as day
from learning_pradeep.sql_exe.dim_customer
