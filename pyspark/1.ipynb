# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.table('learning_pradeep.pyspark_training.dim_customers')

# %%
df.show()

# %%
df.printSchema()

# %%
#select 

df.select('country','state').display()

# %%
df.select(df.country.alias('country_name'),df.state.alias('state_name')).display()

# %%
df.drop('email').show()

# %% [markdown]
# # sorting and ordering

# %%
df.orderBy("state").show()

# %%
df.select("country").distinct().show()

# %%
df.filter(col("created_date") > '2023-02-14').show()

# %%
df.na.replace('USA','united_states').show()
