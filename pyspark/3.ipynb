# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
df1 = spark.read.table('learning_pradeep.pyspark_training.dim_customers') 

df1.display()

# %%
df2 = spark.read.table('learning_pradeep.pyspark_training.fact_orders')
df2.display()

# %%
df_fjoin = df2.join(df1)

display(df)

# %%
df = df2.join(df1, 'customer_id' , "inner")

df.select('customer_id','customer_name','order_date' , 'status').show()
