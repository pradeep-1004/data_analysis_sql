# %%
# %sql
USE learning_pradeep.spark_exe

# %%
df = spark.read.table('orders')

df.show()

# %%
df1 = df.dropna().show()

# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import *

# %%
df.groupBy("customer_id").agg(sum("amount"),count("*").alias("total_orders")).display()

# %%
df.groupBy("customer_id").agg(sum("amount"),count("*").alias("total_orders")).display()

df.filter('amount >= 50000').show()
